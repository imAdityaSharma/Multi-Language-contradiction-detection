# %%
import pandas as pd
from nltk.tokenize import word_tokenize as wt 
from nltk.corpus import stopwords
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem import wordnet
from nltk.stem import WordNetLemmatizer
import spacy

# %%
train_df = pd.read_csv('test.csv',header=0)

# %%
train_df
# Out:
#               id                                            premise  \
# 0     c6d58c3f69  بکس، کیسی، راہیل، یسعیاہ، کیلی، کیلی، اور کولم...
# 1     cefcc82292                             هذا هو ما تم نصحنا به.
# 2     e98005252c  et cela est en grande partie dû au fait que le...
# 3     58518c10ba                   与城市及其他公民及社区组织代表就IMA的艺术发展进行对话&amp
# 4     c32b0d16df                              Она все еще была там.
# ...          ...                                                ...
# 5190  5f90dd59b0     نیند نے وعدہ کیا کہ موٹل نے سوال میں تحقیق کی.
# 5191  f357a04e86  The  rock  has a soft texture and can be bough...
# 5192  1f0ea92118                      她目前的存在，并考虑到他与沃佛斯顿争执的本质，那是尴尬的。
# 5193  0407b48afb  isn't it i can remember i've only been here ei...
# 5194  16c2f2ab89  In Hong Kong you can have a plate, or even a w...
#
#                                              hypothesis lang_abv language
# 0     کیسی کے لئے کوئی یادگار نہیں ہوگا, کولمین ہائی...       ur     Urdu
# 1     عندما يتم إخبارهم بما يجب عليهم فعله ، فشلت ال...       ar   Arabic
# 2                                Les mères se droguent.       fr   French
# 3                               IMA与其他组织合作，因为它们都依靠共享资金。       zh  Chinese
# 4        Мы думали, что она ушла, однако, она осталась.       ru  Russian
# ...                                                 ...      ...      ...
# 5190  نیمیتھ کو موٹل کی تفتیش کے لئے معاوضہ دیا جارہ...       ur     Urdu
# 5191        The rock is harder than most types of rock.       en  English
# 5192                她在与Wolverstone的打斗结束后才在场的事实被看作是很尴尬的。       zh  Chinese
# 5193  I could see downtown Dallas from where I lived...       en  English
# 5194  It's impossible to have a plate hand-painted t...       en  English
#
# [5195 rows x 5 columns]

# %%
train_df.sample(10)
# Out:
#               id                                            premise  \
# 2728  76b3a8e246  The majority of the agencies that responded ap...
# 85    479c4ad2a4  He jumped up, planting one hand on the chargin...
# 3997  743fdb7eb8  (For more information on BLM's senior executiv...
# 1493  2dc6af9fc3  Bạn có thể đã nghe nói về tôi. Thuyền trưởng C...
# 4922  5c383faee2  سی آئی او اور فیصلہ سازی حکام کا فیصلہ ہے کہ ب...
# 1002  e22948f69d  NOx can be transported long distances and cont...
# 1812  2e01c25e30  A fresh access of pain seized the unfortunate ...
# 3512  566d7a2078  Και γνωρίζουμε ότι ο καθηγητής Honey έχει δίκι...
# 2685  525d29b4ad  Then it occurred to me that the criminal stand...
# 1448  21cf457279  کیا تم بغاوت, غداری اور کورٹ مارشل کی یہ بکواس...
#
#                                              hypothesis lang_abv    language
# 2728  The agencies that responded appreciated the in...       en     English
# 85    He swung his axe at the brute to knock him off...       en     English
# 3997                BLM's performance plans are secret.       en     English
# 1493             Thuyền trưởng Calverley không còn mắt.       vi  Vietnamese
# 4922  سی آئی او کام  کے اجازت متعلک ھونے والے  کسی ب...       ur        Urdu
# 1002  NOx can not move far from its source, so it do...       en     English
# 1812   The elderly lady was close to death and in pain.       en     English
# 3512  Υποθέτουμε ότι ο καθηγητής Honey είναι σωστός ...       el       Greek
# 2685  I then realized that criminals have small ideals.       en     English
# 1448  بلڈ کے پاس ایک ٹوپی تھی جو وہ بیٹھنے سے پہلے پ...       ur        Urdu
